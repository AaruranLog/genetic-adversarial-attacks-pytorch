# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from __future__ import print_function
import argparse
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR
from torch.distributions.categorical import Categorical
from torchsummary import summary
import matplotlib.pyplot as plt
import genattack_class as GA
import time
#import efficientnet as EN

# %%
## Neural Network Architecture for MNIST and similar datasets
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.dropout1 = nn.Dropout2d(0.25)
        self.dropout2 = nn.Dropout2d(0.5)
        self.fc1 = nn.Linear(9216, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc2(x)
        output = F.log_softmax(x, dim=1)
        return output

# %%
## Neural Network Architecture for CIFAR-10
class Net2(nn.Module):
    def __init__(self):
        super(Net2, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        output = F.log_softmax(x, dim=1)
        return output

# %%
def adv_train(model, device, train_loader, optimizer, epoch, epsilon=0.1, alpha=0.5):
    log_interval = 120
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        #print(data.shape)
        data.requires_grad = True
        
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward(retain_graph=True)

        # Generating Adversarial Examples
        # Collect gradient of inputs
        data_grad = data.grad.data

        # FGSM Attack
        perturbed_data = fgsm_attack(data, epsilon, data_grad)

        # Get loss from perturbed data
        adv_output = model(perturbed_data)
        adv_loss = F.nll_loss(adv_output, target)


        optimizer.zero_grad()

        # Calculate total loss
        total_loss = alpha*loss + (1-alpha)*adv_loss
        total_loss.backward()

        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

# %%
def train(model, device, train_loader, optimizer, epoch, epsilon=0.1, alpha=0.5):
    log_interval = 120
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad() 
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

# %%
def fgsm_attack(image, epsilon, data_grad):
    # Collect the element-wise sign of the data gradient
    sign_data_grad = data_grad.sign()
    # Create the perturbed image by adjusting each pixel of the input image
    perturbed_image = image + epsilon*sign_data_grad
    # Adding clipping to maintain [0,1] range
    perturbed_image = torch.clamp(perturbed_image, 0, 1)
    # Return the perturbed image
    return perturbed_image

# %%
def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
def adv_test(model, device, test_loader, epsilon=0.1):
    model.eval()
    test_loss = 0
    correct = 0
    adv_examples = []
    for batch_data, batch_target in test_loader:
      for i in range(batch_data.shape[0]):
        data = batch_data[i].unsqueeze(0)
        target = batch_target[i].unsqueeze(0)
        data, target = data.to(device), target.to(device)
        data.requires_grad = True
        
        output = model(data)
        
        init_pred = output.max(1, keepdim=True)[1]
        
        #print(init_pred)
        if init_pred[0].item() != target.item():
            continue

        loss = F.nll_loss(output, target)
        model.zero_grad()

        loss.backward()

        data_grad = data.grad.data

        perturbed_data = fgsm_attack(data, epsilon, data_grad)

        output = model(perturbed_data)

        final_pred = output.max(1, keepdim=True)[1]
        if final_pred.item() == target.item():
            correct += 1
        else:
            if len(adv_examples) < 5:
                adv_ex = perturbed_data.squeeze().detach().cpu().numpy()
                adv_examples.append((init_pred.item(), final_pred.item(), adv_ex))
        
    final_acc = correct/float(len(test_loader))

    print("Epsilon: {}\tTest Accuracy = {} / {} = {}\n".format(epsilon, correct, len(test_loader), final_acc))
    return final_acc, adv_examples

# %%
def main():
    # Training settings
    batch_size = 100
    test_batch_size = 1000
    lr = 0.1 # learning rate
    gamma = 0.7 # learning rate decay
    epochs = 20
    save_model = True

    use_cuda = torch.cuda.is_available()
    print("CUDA? " + str(use_cuda))

    torch.manual_seed(20294798)

    device = torch.device("cuda" if use_cuda else "cpu")

    kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

    train_loader = torch.utils.data.DataLoader(
        datasets.CIFAR10('../data' ,train=True, download=True,
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                       ])),
        batch_size=batch_size, shuffle=True, **kwargs)
    
    test_loader = torch.utils.data.DataLoader(
        datasets.CIFAR10('../data', train=False, transform=transforms.Compose([
                           transforms.ToTensor(),
                       ])),
        batch_size=test_batch_size, shuffle=True, **kwargs)

    model = EN.EfficientNetB0().to(device)
    model_adv = EN.EfficientNetB0().to(device)

    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9)
    optimizer_adv = optim.SGD(model_adv.parameters(), lr=lr, momentum=0.9)

    #scheduler = StepLR(optimizer, step_size=1, gamma=gamma)
    for epoch in range(1, epochs + 1):
        print("Conventional Model")
        train(model, device, train_loader, optimizer, epoch)
        print("Adversarially trained Model")
        adv_train(model_adv, device, train_loader, optimizer_adv, epoch, epsilon = 0.1)
    print("\nTest on standard model:")
    test(model, device, test_loader)
    #print("Now with adversarial examples")
    #acc, ex = adv_test(model, device, test_loader, epsilon = 0.1)

    print("\nTest on adversarially trained model:")
    test(model_adv, device, test_loader)
    #print("Now with adversarial examples")
    #adv_acc, adv_ex = adv_test(model_adv, device, test_loader, epsilon = 0.1)

        #scheduler.step()

    if save_model:
        torch.save(model.state_dict(), "/content/drive/My Drive/NNProj/MNIST.pt")
        torch.save(model_adv.state_dict(), "/content/drive/My Drive/NNProj/MNIST.pt")

# %%
def seed_init_fn(worker_id):
  np.random.seed(np.random.get_state()[1][0] + worker_id)
  return

# %%
use_cuda = torch.cuda.is_available()
print("CUDA? " + str(use_cuda))

torch.manual_seed(20294798)

device = torch.device("cuda" if use_cuda else "cpu")

kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                    transform=transforms.Compose([
                        transforms.ToTensor(),
                    ])),
    batch_size=100, shuffle=True, **kwargs, worker_init_fn = seed_init_fn)

test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, download=True, transform=transforms.Compose([
                        transforms.ToTensor(),
                    ])),
    batch_size=1, shuffle=True, **kwargs, worker_init_fn = seed_init_fn)
# Out:
# CUDA? True

# %%
def hype_pop(model, pop, testdata):
  model.eval()
  gen = []
  time_ = []
  
  for i, (data, target) in enumerate(testdata):
      if i >= 10000:
        break
      data, target = data.to(device), target.to(device)
      output = model(data)
      pred = output.argmax(dim=1, keepdim=True)

      if pred == target:
          start = time.time()
          adv_ex, success, G = GA.gen_attack(pop, data, target, 0.2, 0.15, 0.1, 5000, 2, model, GA.fitness, device)
          end = time.time()
          gen.append(G)
          time_.append(end-start)

  mean_gen = np.mean(gen)
  mean_time = np.mean(time_)
  return (mean_gen, mean_time)

# %%
def hype_mut(model, rho, testdata):
  model.eval()
  gen = []

  for i, (data, target) in enumerate(testdata):
      if i >= 10000:
        break
      data, target = data.to(device), target.to(device)
      output = model(data)
      pred = output.argmax(dim=1, keepdim=True)

      if pred == target:
          adv_ex, success, G = GA.gen_attack(10, data, target, 0.2, 0.15, rho, 5000, 2, model, GA.fitness, device)
          gen.append(G)

  mean_gen= np.mean(gen)
  return mean_gen

# %%
pretrained_model = "/content/drive/My Drive/NNProj/MNIST.pt"

device = torch.device("cuda" if (use_cuda) else "cpu")

model = Net().to(device)
model.load_state_dict(torch.load(pretrained_model, map_location='cpu'))
model.eval()
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (dropout1): Dropout2d(p=0.25, inplace=False)
#   (dropout2): Dropout2d(p=0.5, inplace=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
pops = [5, 10, 15, 20, 25]
MNIST_pop_gen = []
MNIST_pop_time = []
for pop in pops:
  print(pop)
  i, j = hype_pop(model, pop, test_loader)
  MNIST_pop_gen.append(i)
  MNIST_pop_time.append(j)
# Out:
# Streaming output truncated to the last 5000 lines.
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Plateau at Generation 101
# Generation 100
# Generation 200
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Generation 200
# Generation 300
# Generation 100
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 100
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 500
# Plateau at Generation 563
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 353
# Generation 400
# Generation 100
# Generation 200
# Generation 300
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 500
# Generation 600
# Plateau at Generation 605
# Generation 700
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Generation 200
# Generation 300
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Generation 200
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Generation 200
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Generation 100
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Generation 200
# Generation 300
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# ...
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Generation 600
# Generation 700
# Generation 800
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 339
# Generation 400
# Generation 500
# Generation 600
# Generation 700
# Plateau at Generation 724
# Generation 800
# Generation 900
# Generation 1000
# Generation 1100
# Generation 1200
# Plateau at Generation 1219
# Generation 1300
# Generation 1400
# Plateau at Generation 1428
# Generation 1500
# Plateau at Generation 1528
# Generation 1600
# Plateau at Generation 1628
# Generation 1700
# Plateau at Generation 1728
# Generation 1800
# Plateau at Generation 1828
# Generation 1900
# Plateau at Generation 1928
# Generation 2000
# Plateau at Generation 2028
# Generation 2100
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# 10
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 384
# Generation 400
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 321
# Generation 100
# Generation 200
# Generation 300
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Plateau at Generation 466
# Generation 500
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Plateau at Generation 279
# Generation 300
# Generation 400
# Generation 500
# Plateau at Generation 556
# Generation 600
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Plateau at Generation 469
# Generation 500
# Generation 600
# Generation 700
# Generation 100
# 15
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 500
# Plateau at Generation 537
# Generation 600
# Plateau at Generation 637
# Generation 700
# Plateau at Generation 737
# Generation 800
# Plateau at Generation 837
# Generation 900
# Plateau at Generation 937
# Generation 1000
# Plateau at Generation 1037
# Generation 1100
# Plateau at Generation 1137
# Generation 1200
# Plateau at Generation 1237
# Generation 1300
# Plateau at Generation 1337
# Generation 1400
# Plateau at Generation 1437
# Generation 1500
# Plateau at Generation 1537
# Generation 1600
# Plateau at Generation 1637
# Generation 1700
# Plateau at Generation 1737
# Generation 1800
# Plateau at Generation 1837
# Generation 1900
# Plateau at Generation 1937
# Generation 2000
# Plateau at Generation 2037
# Generation 2100
# Plateau at Generation 2137
# Generation 2200
# Plateau at Generation 2237
# Generation 2300
# Plateau at Generation 2337
# Generation 2400
# Plateau at Generation 2437
# Generation 2500
# Plateau at Generation 2537
# Generation 2600
# Plateau at Generation 2637
# Generation 2700
# Plateau at Generation 2737
# Generation 2800
# Plateau at Generation 2837
# Generation 2900
# Plateau at Generation 2937
# Generation 3000
# Plateau at Generation 3037
# Generation 3100
# Plateau at Generation 3137
# Generation 3200
# Plateau at Generation 3237
# Generation 3300
# Plateau at Generation 3337
# Generation 3400
# Plateau at Generation 3437
# Generation 3500
# Plateau at Generation 3537
# Generation 3600
# Plateau at Generation 3637
# Generation 3700
# Plateau at Generation 3737
# Generation 3800
# Plateau at Generation 3837
# Generation 3900
# Plateau at Generation 3937
# Generation 4000
# Plateau at Generation 4037
# Generation 4100
# Plateau at Generation 4137
# Generation 4200
# Plateau at Generation 4237
# Generation 4300
# Plateau at Generation 4337
# Generation 4400
# Plateau at Generation 4437
# Generation 4500
# Plateau at Generation 4537
# Generation 4600
# Plateau at Generation 4637
# Generation 4700
# Plateau at Generation 4737
# Generation 4800
# Plateau at Generation 4837
# Generation 4900
# Plateau at Generation 4937
# Generation 100
# Generation 200
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 308
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 361
# Generation 400
# Generation 500
# Generation 600
# Generation 700
# Plateau at Generation 775
# Generation 800
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Plateau at Generation 101
# Generation 200
# Generation 100
# Plateau at Generation 147
# Generation 200
# Generation 300
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# 20
# Generation 100
# Generation 200
# Plateau at Generation 206
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 500
# Plateau at Generation 524
# Generation 600
# Generation 700
# Plateau at Generation 726
# Generation 800
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Plateau at Generation 444
# Generation 500
# Plateau at Generation 544
# Generation 600
# Plateau at Generation 644
# Generation 700
# Plateau at Generation 744
# Generation 800
# Plateau at Generation 844
# Generation 900
# Plateau at Generation 944
# Generation 1000
# Plateau at Generation 1044
# Generation 1100
# Generation 100
# Generation 200
# Plateau at Generation 238
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 100
# Generation 200
# Generation 100
# Plateau at Generation 193
# Generation 200
# Plateau at Generation 293
# Generation 300
# Generation 400
# Generation 500
# Generation 600
# Plateau at Generation 663
# Generation 700
# Generation 800
# Generation 900
# Generation 1000
# Generation 1100
# Plateau at Generation 1162
# Generation 1200
# Plateau at Generation 1262
# Generation 1300
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# 25
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 500
# Plateau at Generation 589
# Generation 600
# Generation 700
# Generation 800
# Plateau at Generation 814
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 300
# Generation 100
# Generation 200
# Plateau at Generation 274
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 306
# Generation 400
# Plateau at Generation 406
# Generation 500
# Plateau at Generation 506
# Generation 600
# Plateau at Generation 606
# Generation 700
# Plateau at Generation 706
# Generation 800
# Plateau at Generation 806
# Generation 900
# Plateau at Generation 906
# Generation 1000
# Plateau at Generation 1006
# Generation 1100
# Plateau at Generation 1106
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 500
# Plateau at Generation 501
# Generation 600
# Generation 700
# Plateau at Generation 723
# Generation 800
# Plateau at Generation 823
# Generation 900
# Plateau at Generation 923
# Generation 1000
# Plateau at Generation 1023
# Generation 1100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 100

# %%
import csv
with open('MNIST_pop.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(pops)
    writer.writerow(MNIST_pop_gen)
    writer.writerow(MNIST_pop_time)

# %%
prob = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3]
MNIST_rho_time = []
for rho in prob:
  print(rho)
  j = hype_mut(model, rho, test_loader)
  MNIST_rho_time.append(j)
# Out:
# 0.05
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 500
# Plateau at Generation 513
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Plateau at Generation 184
# Generation 200
# Plateau at Generation 284
# Generation 300
# Plateau at Generation 384
# Generation 400
# Plateau at Generation 484
# Generation 500
# Generation 100
# Generation 200
# Generation 300
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 354
# Generation 400
# Plateau at Generation 454
# Generation 500
# Plateau at Generation 554
# Generation 600
# Plateau at Generation 654
# Generation 700
# Plateau at Generation 754
# Generation 800
# Plateau at Generation 854
# Generation 900
# Plateau at Generation 954
# Generation 1000
# Plateau at Generation 1054
# Generation 1100
# Plateau at Generation 1154
# Generation 1200
# Plateau at Generation 1254
# Generation 1300
# Plateau at Generation 1354
# Generation 1400
# Plateau at Generation 1454
# Generation 1500
# Plateau at Generation 1554
# Generation 1600
# Plateau at Generation 1654
# Generation 1700
# Plateau at Generation 1754
# Generation 1800
# Plateau at Generation 1854
# Generation 1900
# Plateau at Generation 1954
# Generation 2000
# Plateau at Generation 2054
# Generation 2100
# Plateau at Generation 2154
# Generation 2200
# Plateau at Generation 2254
# Generation 2300
# Plateau at Generation 2354
# Generation 2400
# Plateau at Generation 2454
# Generation 2500
# Plateau at Generation 2554
# Generation 2600
# Plateau at Generation 2654
# Generation 2700
# Plateau at Generation 2754
# Generation 2800
# Plateau at Generation 2854
# Generation 2900
# Plateau at Generation 2954
# Generation 3000
# Plateau at Generation 3054
# Generation 3100
# Plateau at Generation 3154
# Generation 3200
# Plateau at Generation 3254
# Generation 3300
# Plateau at Generation 3354
# Generation 3400
# Plateau at Generation 3454
# Generation 3500
# Plateau at Generation 3554
# Generation 3600
# Plateau at Generation 3654
# Generation 3700
# Plateau at Generation 3754
# Generation 3800
# Plateau at Generation 3854
# Generation 3900
# Plateau at Generation 3954
# Generation 4000
# Plateau at Generation 4054
# Generation 4100
# Plateau at Generation 4154
# Generation 4200
# Plateau at Generation 4254
# Generation 4300
# Plateau at Generation 4354
# Generation 4400
# Plateau at Generation 4454
# Generation 4500
# Plateau at Generation 4554
# Generation 4600
# Plateau at Generation 4654
# Generation 4700
# Plateau at Generation 4754
# Generation 4800
# Plateau at Generation 4854
# Generation 4900
# Plateau at Generation 4954
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 500
# Generation 600
# Generation 700
# Plateau at Generation 745
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Plateau at Generation 231
# Generation 300
# Plateau at Generation 331
# Generation 100
# Generation 200
# Plateau at Generation 233
# Generation 300
# Plateau at Generation 333
# Generation 400
# Plateau at Generation 433
# Generation 500
# Plateau at Generation 533
# Generation 600
# Plateau at Generation 633
# Generation 700
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Plateau at Generation 456
# Generation 500
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 500
# Plateau at Generation 555
# Generation 600
# Generation 700
# Generation 800
# Generation 900
# Generation 1000
# Plateau at Generation 1052
# Generation 1100
# Plateau at Generation 1179
# Generation 1200
# Generation 1300
# Plateau at Generation 1379
# Generation 1400
# Plateau at Generation 1479
# Generation 1500
# Plateau at Generation 1579
# Generation 1600
# Plateau at Generation 1679
# Generation 1700
# Generation 1800
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 200
# 0.1
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 352
# Generation 400
# Plateau at Generation 452
# Generation 500
# Generation 600
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 500
# Plateau at Generation 568
# Generation 600
# Generation 700
# Generation 100
# Plateau at Generation 180
# Generation 200
# Generation 300
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 500
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Plateau at Generation 166
# Generation 200
# Generation 100
# Generation 200
# Plateau at Generation 227
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 341
# Generation 400
# Generation 500
# Plateau at Generation 597
# Generation 600
# Generation 700
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 396
# Generation 400
# Generation 500
# Generation 600
# Generation 700
# Plateau at Generation 763
# Generation 800
# Generation 900
# Plateau at Generation 911
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 500
# Plateau at Generation 529
# Generation 600
# Plateau at Generation 629
# Generation 700
# Generation 800
# Plateau at Generation 857
# Generation 900
# Generation 1000
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# 0.15
# Generation 100
# Generation 200
# Plateau at Generation 259
# Generation 300
# Generation 400
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 500
# Generation 600
# Plateau at Generation 635
# Generation 700
# Plateau at Generation 766
# Generation 800
# Plateau at Generation 866
# Generation 900
# Plateau at Generation 966
# Generation 1000
# Plateau at Generation 1066
# Generation 1100
# Plateau at Generation 1166
# Generation 1200
# Plateau at Generation 1266
# Generation 1300
# Plateau at Generation 1366
# Generation 1400
# Plateau at Generation 1466
# Generation 1500
# Plateau at Generation 1566
# Generation 100
# Generation 200
# Plateau at Generation 299
# Generation 300
# Plateau at Generation 399
# Generation 400
# Plateau at Generation 499
# Generation 500
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 308
# Generation 400
# Plateau at Generation 493
# Generation 500
# Generation 600
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 392
# Generation 400
# Plateau at Generation 492
# Generation 500
# Plateau at Generation 592
# Generation 600
# Plateau at Generation 692
# Generation 700
# Plateau at Generation 792
# Generation 800
# Plateau at Generation 892
# Generation 900
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 374
# Generation 400
# Plateau at Generation 474
# Generation 500
# Plateau at Generation 574
# Generation 600
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 100
# Generation 100
# Generation 200
# Plateau at Generation 204
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Plateau at Generation 400
# Generation 500
# Plateau at Generation 547
# Generation 600
# Generation 700
# Plateau at Generation 773
# Generation 800
# Plateau at Generation 873
# Generation 900
# Plateau at Generation 973
# Generation 1000
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 500
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Plateau at Generation 417
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 300
# Generation 100
# 0.2
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 345
# Generation 400
# Plateau at Generation 477
# Generation 500
# Generation 600
# Generation 100
# Generation 100
# Generation 200
# Plateau at Generation 225
# Generation 300
# Plateau at Generation 390
# Generation 400
# Plateau at Generation 490
# Generation 500
# Plateau at Generation 590
# Generation 600
# Plateau at Generation 690
# Generation 700
# Generation 100
# Generation 100
# Plateau at Generation 101
# Generation 100
# Generation 200
# Plateau at Generation 255
# Generation 300
# Plateau at Generation 355
# Generation 400
# Plateau at Generation 455
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Plateau at Generation 101
# Generation 200
# Plateau at Generation 201
# Generation 300
# Plateau at Generation 301
# Generation 400
# Plateau at Generation 401
# Generation 500
# Plateau at Generation 501
# Generation 600
# Plateau at Generation 601
# Generation 700
# Plateau at Generation 701
# Generation 800
# Plateau at Generation 801
# Generation 900
# Plateau at Generation 901
# Generation 1000
# Plateau at Generation 1001
# Generation 1100
# Plateau at Generation 1101
# Generation 1200
# Plateau at Generation 1201
# Generation 1300
# Plateau at Generation 1301
# Generation 1400
# Plateau at Generation 1401
# Generation 1500
# Plateau at Generation 1501
# Generation 1600
# Plateau at Generation 1601
# Generation 1700
# Plateau at Generation 1701
# Generation 1800
# Plateau at Generation 1801
# Generation 1900
# Plateau at Generation 1901
# Generation 2000
# Plateau at Generation 2001
# Generation 2100
# Plateau at Generation 2101
# Generation 2200
# Plateau at Generation 2201
# Generation 2300
# Plateau at Generation 2301
# Generation 2400
# Plateau at Generation 2401
# Generation 2500
# Plateau at Generation 2501
# Generation 2600
# Plateau at Generation 2601
# Generation 2700
# Plateau at Generation 2701
# Generation 2800
# Plateau at Generation 2801
# Generation 2900
# Plateau at Generation 2901
# Generation 3000
# Plateau at Generation 3001
# Generation 3100
# Plateau at Generation 3101
# Generation 3200
# Plateau at Generation 3201
# Generation 3300
# Plateau at Generation 3301
# Generation 3400
# Plateau at Generation 3401
# Generation 3500
# Plateau at Generation 3501
# Generation 3600
# Plateau at Generation 3601
# Generation 3700
# Plateau at Generation 3701
# Generation 3800
# Plateau at Generation 3801
# Generation 3900
# Plateau at Generation 3901
# Generation 4000
# Plateau at Generation 4001
# Generation 4100
# Plateau at Generation 4101
# Generation 4200
# Plateau at Generation 4201
# Generation 4300
# Plateau at Generation 4301
# Generation 4400
# Plateau at Generation 4401
# Generation 4500
# Plateau at Generation 4501
# Generation 4600
# Plateau at Generation 4601
# Generation 4700
# Plateau at Generation 4701
# Generation 4800
# Plateau at Generation 4801
# Generation 4900
# Plateau at Generation 4901
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Plateau at Generation 427
# Generation 500
# Plateau at Generation 527
# Generation 600
# Plateau at Generation 627
# Generation 700
# Plateau at Generation 727
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Plateau at Generation 429
# Generation 500
# Plateau at Generation 529
# Generation 600
# Plateau at Generation 629
# Generation 700
# Plateau at Generation 729
# Generation 800
# Generation 900
# Generation 1000
# Generation 100
# Generation 200
# Generation 300
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 308
# Generation 400
# Plateau at Generation 408
# Generation 500
# Plateau at Generation 508
# Generation 600
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 100
# Generation 100
# Generation 100
# 0.25
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 300
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Plateau at Generation 441
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Plateau at Generation 257
# Generation 300
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Plateau at Generation 440
# Generation 500
# Plateau at Generation 540
# Generation 600
# Plateau at Generation 640
# Generation 700
# Plateau at Generation 740
# Generation 800
# Plateau at Generation 840
# Generation 900
# Plateau at Generation 940
# Generation 1000
# Plateau at Generation 1040
# Generation 1100
# Plateau at Generation 1140
# Generation 1200
# Plateau at Generation 1240
# Generation 1300
# Plateau at Generation 1340
# Generation 1400
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Plateau at Generation 211
# Generation 300
# Generation 400
# Generation 500
# Generation 600
# Generation 700
# Plateau at Generation 710
# Generation 800
# Plateau at Generation 810
# Generation 900
# Plateau at Generation 910
# Generation 1000
# Plateau at Generation 1010
# Generation 1100
# Plateau at Generation 1110
# Generation 1200
# Plateau at Generation 1210
# Generation 1300
# Plateau at Generation 1310
# Generation 1400
# Plateau at Generation 1410
# Generation 1500
# Plateau at Generation 1510
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 391
# Generation 400
# Generation 500
# Generation 100
# Generation 200
# Generation 300
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# 0.3
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Plateau at Generation 407
# Generation 500
# Plateau at Generation 507
# Generation 600
# Plateau at Generation 607
# Generation 700
# Plateau at Generation 707
# Generation 800
# Plateau at Generation 807
# Generation 900
# Plateau at Generation 907
# Generation 100
# Generation 200
# Plateau at Generation 222
# Generation 300
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Plateau at Generation 392
# Generation 400
# Plateau at Generation 492
# Generation 500
# Generation 600
# Plateau at Generation 618
# Generation 700
# Generation 800
# Generation 900
# Generation 1000
# Generation 100
# Generation 100
# Generation 200
# Plateau at Generation 258
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 500
# Plateau at Generation 516
# Generation 600
# Generation 100
# Generation 200
# Generation 300
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Generation 200
# Generation 300
# Generation 400
# Generation 100
# Generation 200
# Generation 100
# Generation 200
# Plateau at Generation 262
# Generation 300
# Plateau at Generation 362
# Generation 400
# Plateau at Generation 462
# Generation 500
# Plateau at Generation 562
# Generation 600
# Plateau at Generation 662
# Generation 700
# Plateau at Generation 762
# Generation 800
# Plateau at Generation 862
# Generation 900
# Plateau at Generation 962
# Generation 1000
# Plateau at Generation 1062
# Generation 1100
# Plateau at Generation 1162
# Generation 1200
# Generation 100
# Generation 200
# Plateau at Generation 290
# Generation 300
# Plateau at Generation 390
# Generation 400
# Generation 500
# Generation 600
# Generation 100
# Generation 200
# Generation 300
# Generation 100
# Generation 100
# Generation 200
# Plateau at Generation 253
# Generation 300
# Plateau at Generation 353
# Generation 400
# Plateau at Generation 453
# Generation 500
# Plateau at Generation 553
# Generation 600
# Plateau at Generation 653
# Generation 700
# Plateau at Generation 753
# Generation 800
# Plateau at Generation 853
# Generation 900
# Plateau at Generation 953
# Generation 1000
# Plateau at Generation 1053
# Generation 1100
# Plateau at Generation 1153
# Generation 1200
# Plateau at Generation 1253
# Generation 1300
# Plateau at Generation 1353
# Generation 1400
# Plateau at Generation 1453
# Generation 1500
# Plateau at Generation 1553
# Generation 1600
# Plateau at Generation 1653
# Generation 1700
# Plateau at Generation 1753
# Generation 1800
# Plateau at Generation 1853
# Generation 1900
# Plateau at Generation 1953
# Generation 2000
# Plateau at Generation 2053
# Generation 2100
# Plateau at Generation 2153
# Generation 2200
# Generation 100
# Generation 200
# Plateau at Generation 200
# Generation 300
# Plateau at Generation 323
# Generation 400
# Plateau at Generation 423
# Generation 100
# Generation 100
# Plateau at Generation 183
# Generation 200
# Plateau at Generation 283
# Generation 300
# Generation 100
# Generation 100
# Generation 200
# Plateau at Generation 200
# Generation 100
# Generation 100
# Generation 100
# Generation 100
# Plateau at Generation 197
# Generation 200

# %%
with open('MNIST_rho.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(prob)
    writer.writerow(MNIST_rho_time)
